# %% [markdown]
# # 📘 02 - Control Flow
#
# Learn how to use conditional logic in Python.

# %% [markdown]
# ## ✅ Learning Goals
# - Write `if`, `elif`, `else` statements
# - Understand truthy/falsy values
# - Combine conditions using `and`, `or`, `not`

# %%
# 🔧 Basic example
age = 20
if age >= 18:
    print('You are an adult.')
else:
    print('You are a minor.')

# %% [markdown]
# ## 🔀 Multiple Branches

# %%
temp = 72
if temp > 90:
    print('Too hot!')
elif temp < 60:
    print('Too cold!')
else:
    print('Just right.')

# %% [markdown]
# ### ✏️ Your Turn
# Use `input()` to ask a user their grade and print a message based on value.

# %%
# Ask the user for a numeric grade and print a letter grade
grade = int(input('Enter your score: '))

if grade >= 90:
    print('A')
elif grade >= 80:
    print('B')
elif grade >= 70:
    print('C')
elif grade >= 60:
    print('D')
else:
    print('F')
