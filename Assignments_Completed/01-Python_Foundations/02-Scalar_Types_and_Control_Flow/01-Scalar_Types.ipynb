# %% [markdown]
# # 📘 01 - Scalar Types
#
# Review and practice working with Python's basic scalar data types.

# %% [markdown]
# ## ✅ Learning Goals
# - Recognize scalar types (`int`, `float`, `str`, `bool`)
# - Use the `type()` function to identify types
# - Use variables and assignment

# %%
# 🔧 Define some variables
num = 42
pi = 3.14159
name = 'Python'
is_cool = True

# %%
# 🔍 Check their types
print(type(num))
print(type(pi))
print(type(name))
print(type(is_cool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### ✏️ Your Turn
# Create your own variables of each type and print them.

# %%
# Your code here
my_integer = 4543
my_float = 98.6
my_string = 'Spatial Data'
my_boolean = True

print(my_integer, type(my_integer))
print(my_float, type(my_float))
print(my_string, type(my_string))
print(my_boolean, type(my_boolean))
# Out:
# 4543 <class 'int'>
# 98.6 <class 'float'>
# Spatial Data <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ## ⚖️ Comparison Practice
# Use comparison operators to check values.

# %%
x = 10
y = 5
print(x > y)
print(x == y)
print(x != y)
# Out:
# True
# False
# True

# %% [markdown]
# ## 🧠 Quick Check
# What will the following print?
# ```python
# print(3.0 == 3)
# ```
#
# Answer: True, python compares numeric values
