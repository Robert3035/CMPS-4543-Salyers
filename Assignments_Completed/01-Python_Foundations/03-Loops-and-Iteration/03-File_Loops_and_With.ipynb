# %% [markdown]
# # 📘 03 - File Loops and `with`
#
# Use `with open(...)` to read files and process content.

# %% [markdown]
# ## ✅ Learning Goals
# - Open and read files using `with`
# - Loop over lines in a file
# - Use `.strip()` and `.split()` to process text

# %%
# 📝 Sample file read
with open('sample.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# sample
# text
# third line
# more stuff
# if you're reading this I'm sorry
# please give me a good grade
# third line with more than 3 words

# %%
# 🔍 Process each line
with open('sample.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        print('Parts:', parts)
# Out:
# Parts: ['sample']
# Parts: ['text']
# Parts: ['third line']
# Parts: ['more stuff']
# Parts: ["if you're reading this I'm sorry"]
# Parts: ['please give me a good grade']
# Parts: ['third line with more than 3 words']

# %% [markdown]
# ### ✏️ Your Turn
# Open a text file and print all lines that contain more than 3 words.

# %%
# Tip: use `len(line.split()) > 3` to check
with open('sample.txt', 'r') as f:
    for line in f:
        if len(line.split()) > 3:
            print(line.strip())
# Out:
# if you're reading this I'm sorry
# please give me a good grade
# third line with more than 3 words
