# %% [markdown]
# # 📘 03 - Python Dictionaries
#
# Dictionaries store key-value pairs for fast lookups.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access dictionary items
# - Use dictionary methods like `.get()` and `.items()`

# %%
# 📚 Create a Dictionary
student = {'name': 'Alex', 'age': 21, 'major': 'CS'}
print(student)
# Out:
# {'name': 'Alex', 'age': 21, 'major': 'CS'}

# %%
# 🔍 Access Values
print(student['name'])
print(student.get('gpa', 'N/A'))
# Out:
# Alex
# N/A

# %%
# 🔁 Loop Over Dictionary
for key, value in student.items():
    print(key, '->', value)
# Out:
# name -> Alex
# age -> 21
# major -> CS

# %% [markdown]
# ## ✏️ Your Turn
# Create a dictionary to store information about your favorite book.

# %%
favorite_book = {
    'title': 'The Messiah\'s Handbook',
    'author': 'Richard Back',
    'genre': 'Non-fiction',
    'year_published': 2004,
    'rating': 5
}

print(favorite_book)
print('Title:', favorite_book['title'])
print('Author:', favorite_book['author'])

for key, value in favorite_book.items():
    print(key, '->', value)
# Out:
# {'title': "The Messiah's Handbook", 'author': 'Richard Back', 'genre': 'Non-fiction', 'year_published': 2004, 'rating': 5}
# Title: The Messiah's Handbook
# Author: Richard Back
# title -> The Messiah's Handbook
# author -> Richard Back
# genre -> Non-fiction
# year_published -> 2004
# rating -> 5
