# %% [markdown]
# # ⏱️ 08 - Timing and Performance
#
# In data science, performance matters. Some code runs fast, some slow.
# Jupyter/IPython gives us tools to measure runtime easily.
#
# In this notebook you will learn:
# - `%time` and `%timeit` for single expressions
# - `%%time` and `%%timeit` for entire cells
# - Comparing loops, list comprehensions, and NumPy
# - Why performance awareness is important

# %% [markdown]
# ## 1. `%time`

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 12.9 ms, sys: 991 μs, total: 13.9 ms
# Wall time: 15.9 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Use `%time` to measure how long it takes to sort a list of 1 million random numbers.

# %% [markdown]
# ## 2. `%timeit`

# %%
numbers = list(range(1_000))
# %timeit [x**2 for x in numbers]
# Out:
# 49.2 μs ± 10.2 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Compare `%timeit` results for a list comprehension vs. a `for` loop that builds the same list.

# %%
# Compare %timeit results for a list comprehension vs. a for loop that builds the same list.
# %timeit [x for x in numbers]
# %timeit numbers2 = []; [numbers2.append(x) for x in numbers]
# Out:
# 11 μs ± 786 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 27.5 μs ± 2.25 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## 3. `%%time` for a Whole Cell

# %%
# %%timeit
total = 0
for i in range(1_000_000):
    total += i
total
# Out:
# 41.9 ms ± 6.02 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ✅ **Your Turn**: Wrap a longer multi-line operation with `%%time` to measure its runtime.

# %%
# %%timeit
total = 0
for i in range(1_000):
    total += i**2
total
# Out:
# 62.9 μs ± 16.5 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## 4. Comparing Loops vs. NumPy

# %%
import numpy as np

numbers = np.arange(1_000_000)

# Python loop
# %timeit [x**2 for x in numbers]

# NumPy vectorized
# %timeit numbers**2
# Out:
# 111 ms ± 10.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 231 μs ± 24.7 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Try squaring numbers with a Python loop, list comprehension, and NumPy array. Compare times.

# %%
# %%timeit
import numpy as np
#square numbers with a Python loop, list comprehension, and NumPy array. Compare times

numbers = list(range(1000))
squares = []

#python loop
squares = []
for x in numbers:
    squares.append(x**2)
# Out:
# 69 μs ± 10.7 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
#list comprehension
squares = [x**2 for x in numbers]
# Out:
# 53.9 μs ± 12.9 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
#NumPy array
numbers_np = np.array(numbers)
squares_np = numbers_np**2
# Out:
# 40.9 μs ± 14 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## 5. Why This Matters
# - Performance differences become huge with large datasets.
# - Vectorized operations (like NumPy, Pandas) are usually faster.
# - `%timeit` is your friend when deciding how to implement something.

# %% [markdown]
# ---
# ### Summary
# - `%time` and `%timeit` measure execution speed.
# - `%%time` and `%%timeit` work on whole cells.
# - Loops are slower than list comprehensions, which are slower than NumPy.
# - Always measure performance before optimizing.
