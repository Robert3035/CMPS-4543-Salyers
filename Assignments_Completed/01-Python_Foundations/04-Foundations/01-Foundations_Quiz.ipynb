# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# *Your Answer:*
# `%whos` displays currently defined variables, their types, and basic information such as size or value preview.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# *Your Answer:*
# ## My Hobbies
# - Pokemon
# - Rocket League
# - who has three hobbies

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd
# Out:
# '/workspaces/CMPS-4543-Salyers/Assignments/01-Python_Foundations/04-Foundations/Assessments'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open("hello.txt", "w", encoding="utf-8") as f:
    f.write("Hello World")

with open("hello.txt", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# Hello World

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
import pandas as pd

df = pd.DataFrame({"name": ["Ada", "Grace", "Alan", "Katherine", "Guido"], "score": [95, 92, 88, 97, 90]})
df.to_csv("students.csv", index=False)
pd.read_csv("students.csv").head()
# Out:
#         name  score
# 0        Ada     95
# 1      Grace     92
# 2       Alan     88
# 3  Katherine     97
# 4      Guido     90

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [n ** 2 for n in x]
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y = x^2")
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# *Your Answer:*
# Pressing `D` twice deletes a cell.

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np
nums = list(range(10000))
arr = np.arange(10000)
# %timeit [n ** 2 for n in nums]
# %timeit arr ** 2
# Out:
# 490 μs ± 107 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.22 μs ± 991 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# *Your Answer:*
# Markdown makes notebooks readable by explaining the purpose, steps, and results around the code. Mixing Markdown and code helps turn the notebook into a report that someone else can follow and reproduce.
